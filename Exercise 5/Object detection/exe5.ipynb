# %% [markdown]
# <a href="https://colab.research.google.com/github/Nish-hub94/ML-for-Computer-vision/blob/main/Exercise%205/Object%20detection/exe5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install imgaug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 24.3 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/jboutell/keras-YOLOv3-model-set.git
# Out:
# Cloning into 'keras-YOLOv3-model-set'...
# remote: Enumerating objects: 4184, done.
# remote: Counting objects: 100% (713/713), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 4184 (delta 647), reused 589 (delta 579), pack-reused 3471 (from 1)
# Receiving objects: 100% (4184/4184), 66.88 MiB | 29.53 MiB/s, done.
# Resolving deltas: 100% (3020/3020), done.

# %%
# %cd keras-YOLOv3-model-set/
# !python yolo.py --model_type=tiny_yolo2_darknet --weights_path=weights/yolov2-tiny.h5 --anchors_path=configs/yolo2-tiny_anchors.txt --model_input_shape=416x416 --input=example/dog.jpg --image
# Out:
# /content/keras-YOLOv3-model-set
# 2026-01-05 10:49:04.039832: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-05 10:49:04.045054: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-05 10:49:04.058697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767610144.085037    2804 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767610144.092566    2804 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from PIL import Image
display(Image.open('output.png',mode='r'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x576>
